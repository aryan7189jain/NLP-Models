# %%
from bs4 import BeautifulSoup
import re
import emoji
import string
import contractions
from symspellpy import SymSpell
import pkg_resources
import nltk
    
resources = [
        'punkt',
        'punkt_tab',
        'stopwords',
        'wordnet',
        'omw-1.4',
        'averaged_perceptron_tagger_eng'
    ]
    
for resource in resources:
        nltk.download(resource)
    
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.util import ngrams
# Out:
# C:\Users\Think\AppData\Local\Temp\ipykernel_11476\1303338453.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Think\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Think\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Think\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Think\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Think\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Think\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
def process_data(text):
       
    text = BeautifulSoup(text, "html.parser").text
          
    text = contractions.fix(text)
     
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    
    text = re.sub(r'\S+@\S+', '', text)
    
    text = re.sub(r'\+?\d[\d\s-]{8,}\d', '', text)
       
    text = emoji.replace_emoji(text, replace='')
    
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    text = text.lower()
    
    dictionary_path = pkg_resources.resource_filename(
        "symspellpy",
        "frequency_dictionary_en_82_765.txt"
    )
    
    # Create object
    sym_spell = SymSpell(max_dictionary_edit_distance=2)
    
    # Load dictionary
    dictionary_path = pkg_resources.resource_filename(
        "symspellpy",
        "frequency_dictionary_en_82_765.txt"
    )
    
    sym_spell.load_dictionary(
        dictionary_path,
        term_index=0,
        count_index=1
    )
    
    
    suggestions = sym_spell.lookup_compound(
        text,
        max_edit_distance=2
    )
    
    text=suggestions[0].term
    
    tokens = word_tokenize(text)
    
    stop_words = set(stopwords.words('english'))
    
    tokens = [word for word in tokens if word not in stop_words]
    
    lemmatizer = WordNetLemmatizer()
    
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    text = " ".join(tokens)
    
    return text

# %%
folder_path = r"C:\Users\Think\Desktop\anacondaaa\nlp\NLP Models\plagiarism"

documents = {}

for file in os.listdir(folder_path):
    if file.endswith(".txt"):
        file_path = os.path.join(folder_path, file)

        with open(file_path, "r", encoding="utf-8") as f:
            documents[file] = f.read()

print("Total Documents:", len(documents))
# Out:
# Total Documents: 2

# %%
processed_documents = {}
for filename, text in documents.items():
    processed_documents[filename] = process_data(text)

filename = list(documents.keys())[0]

# %%
print(len(processed_documents))
# Out:
# 2

# %%
def ngram_similarity(text1, text2, n=2):

    grams1 = set(ngrams(text1.split(), n))
    grams2 = set(ngrams(text2.split(), n))

    intersection = grams1.intersection(grams2)
    union = grams1.union(grams2)

    if len(union) == 0:
        return 0

    return len(intersection) / len(union)

# %%
filenames = list(processed_documents.keys())

doc1 = processed_documents[filenames[0]]
doc2 = processed_documents[filenames[1]]

# %%
score = ngram_similarity(doc1, doc2, n=2)

print(f"Bigram Similarity : {score*100:.2f}%")
# Out:
# Bigram Similarity : 11.56%

# %%
score = ngram_similarity(doc1, doc2, n=3)

print(f"Trigram Similarity : {score*100:.2f}%")
# Out:
# Trigram Similarity : 3.91%

# %%
folder_path = r"C:\Users\Think\Desktop\anacondaaa\nlp\NLP Models\plagiarism_corpus_20_docs"

documents = {}

for file in os.listdir(folder_path):
    if file.endswith(".txt"):
        file_path = os.path.join(folder_path, file)

        with open(file_path, "r", encoding="utf-8") as f:
            documents[file] = f.read()

print("Total Documents:", len(documents))
# Out:
# Total Documents: 20

# %%
processed_documents = {}
for filename, text in documents.items():
    processed_documents[filename] = process_data(text)

filename = list(documents.keys())[0]

print(len(processed_documents))
# Out:
# 20

# %%
filenames = list(processed_documents.keys())

for i in range(len(filenames)):
    for j in range(i+1, len(filenames)):

        score = ngram_similarity(
            processed_documents[filenames[i]],
            processed_documents[filenames[j]],
            n=2
        )

        print(f"{filenames[i]} <--> {filenames[j]} : {score*100:.2f}%")
# Out:
# doc_001.txt <--> doc_002.txt : 72.41%
# doc_001.txt <--> doc_003.txt : 72.41%
# doc_001.txt <--> doc_004.txt : 72.41%
# doc_001.txt <--> doc_005.txt : 72.41%
# doc_001.txt <--> doc_006.txt : 100.00%
# doc_001.txt <--> doc_007.txt : 72.41%
# doc_001.txt <--> doc_008.txt : 72.41%
# doc_001.txt <--> doc_009.txt : 72.41%
# doc_001.txt <--> doc_010.txt : 72.41%
# doc_001.txt <--> doc_011.txt : 14.00%
# doc_001.txt <--> doc_012.txt : 11.76%
# doc_001.txt <--> doc_013.txt : 11.76%
# doc_001.txt <--> doc_014.txt : 11.76%
# doc_001.txt <--> doc_015.txt : 11.76%
# doc_001.txt <--> doc_016.txt : 0.00%
# doc_001.txt <--> doc_017.txt : 0.00%
# doc_001.txt <--> doc_018.txt : 0.00%
# doc_001.txt <--> doc_019.txt : 0.00%
# doc_001.txt <--> doc_020.txt : 0.00%
# doc_002.txt <--> doc_003.txt : 72.41%
# doc_002.txt <--> doc_004.txt : 72.41%
# doc_002.txt <--> doc_005.txt : 72.41%
# doc_002.txt <--> doc_006.txt : 72.41%
# doc_002.txt <--> doc_007.txt : 100.00%
# doc_002.txt <--> doc_008.txt : 72.41%
# doc_002.txt <--> doc_009.txt : 72.41%
# doc_002.txt <--> doc_010.txt : 72.41%
# doc_002.txt <--> doc_011.txt : 11.76%
# doc_002.txt <--> doc_012.txt : 14.00%
# doc_002.txt <--> doc_013.txt : 11.76%
# doc_002.txt <--> doc_014.txt : 11.76%
# doc_002.txt <--> doc_015.txt : 11.76%
# doc_002.txt <--> doc_016.txt : 0.00%
# doc_002.txt <--> doc_017.txt : 0.00%
# doc_002.txt <--> doc_018.txt : 0.00%
# doc_002.txt <--> doc_019.txt : 0.00%
# doc_002.txt <--> doc_020.txt : 0.00%
# doc_003.txt <--> doc_004.txt : 72.41%
# doc_003.txt <--> doc_005.txt : 72.41%
# doc_003.txt <--> doc_006.txt : 72.41%
# doc_003.txt <--> doc_007.txt : 72.41%
# doc_003.txt <--> doc_008.txt : 100.00%
# doc_003.txt <--> doc_009.txt : 72.41%
# doc_003.txt <--> doc_010.txt : 72.41%
# doc_003.txt <--> doc_011.txt : 11.76%
# doc_003.txt <--> doc_012.txt : 11.76%
# doc_003.txt <--> doc_013.txt : 14.00%
# doc_003.txt <--> doc_014.txt : 11.76%
# doc_003.txt <--> doc_015.txt : 11.76%
# doc_003.txt <--> doc_016.txt : 0.00%
# doc_003.txt <--> doc_017.txt : 0.00%
# doc_003.txt <--> doc_018.txt : 0.00%
# doc_003.txt <--> doc_019.txt : 0.00%
# doc_003.txt <--> doc_020.txt : 0.00%
# doc_004.txt <--> doc_005.txt : 72.41%
# doc_004.txt <--> doc_006.txt : 72.41%
# doc_004.txt <--> doc_007.txt : 72.41%
# doc_004.txt <--> doc_008.txt : 72.41%
# doc_004.txt <--> doc_009.txt : 100.00%
# doc_004.txt <--> doc_010.txt : 72.41%
# doc_004.txt <--> doc_011.txt : 11.76%
# doc_004.txt <--> doc_012.txt : 11.76%
# doc_004.txt <--> doc_013.txt : 11.76%
# doc_009.txt <--> doc_015.txt : 11.76%
# doc_009.txt <--> doc_016.txt : 0.00%
# doc_009.txt <--> doc_017.txt : 0.00%
# doc_009.txt <--> doc_018.txt : 0.00%
# doc_009.txt <--> doc_019.txt : 0.00%
# doc_009.txt <--> doc_020.txt : 0.00%
# doc_010.txt <--> doc_011.txt : 11.76%
# doc_010.txt <--> doc_012.txt : 11.76%
# doc_010.txt <--> doc_013.txt : 11.76%
# doc_010.txt <--> doc_014.txt : 11.76%
# doc_010.txt <--> doc_015.txt : 14.00%
# doc_010.txt <--> doc_016.txt : 0.00%
# doc_010.txt <--> doc_017.txt : 0.00%
# doc_010.txt <--> doc_018.txt : 0.00%
# doc_010.txt <--> doc_019.txt : 0.00%
# doc_010.txt <--> doc_020.txt : 0.00%
# doc_011.txt <--> doc_012.txt : 72.97%
# doc_011.txt <--> doc_013.txt : 72.97%
# doc_011.txt <--> doc_014.txt : 72.97%
# doc_011.txt <--> doc_015.txt : 72.97%
# doc_011.txt <--> doc_016.txt : 0.00%
# doc_011.txt <--> doc_017.txt : 0.00%
# doc_011.txt <--> doc_018.txt : 0.00%
# doc_011.txt <--> doc_019.txt : 0.00%
# doc_011.txt <--> doc_020.txt : 0.00%
# doc_012.txt <--> doc_013.txt : 72.97%
# doc_012.txt <--> doc_014.txt : 72.97%
# doc_012.txt <--> doc_015.txt : 72.97%
# doc_012.txt <--> doc_016.txt : 0.00%
# doc_012.txt <--> doc_017.txt : 0.00%
# doc_012.txt <--> doc_018.txt : 0.00%
# doc_012.txt <--> doc_019.txt : 0.00%
# doc_012.txt <--> doc_020.txt : 0.00%
# doc_013.txt <--> doc_014.txt : 72.97%
# doc_013.txt <--> doc_015.txt : 72.97%
# doc_013.txt <--> doc_016.txt : 0.00%
# doc_013.txt <--> doc_017.txt : 0.00%
# doc_013.txt <--> doc_018.txt : 0.00%
# doc_013.txt <--> doc_019.txt : 0.00%
# doc_013.txt <--> doc_020.txt : 0.00%
# doc_014.txt <--> doc_015.txt : 72.97%
# doc_014.txt <--> doc_016.txt : 0.00%
# doc_014.txt <--> doc_017.txt : 0.00%
# doc_014.txt <--> doc_018.txt : 0.00%
# doc_014.txt <--> doc_019.txt : 0.00%
# doc_014.txt <--> doc_020.txt : 0.00%
# doc_015.txt <--> doc_016.txt : 0.00%
# doc_015.txt <--> doc_017.txt : 0.00%
# doc_015.txt <--> doc_018.txt : 0.00%
# doc_015.txt <--> doc_019.txt : 0.00%
# doc_015.txt <--> doc_020.txt : 0.00%
# doc_016.txt <--> doc_017.txt : 0.00%
# doc_016.txt <--> doc_018.txt : 0.00%
# doc_016.txt <--> doc_019.txt : 0.00%
# doc_016.txt <--> doc_020.txt : 0.00%
# doc_017.txt <--> doc_018.txt : 0.00%
# doc_017.txt <--> doc_019.txt : 0.00%
# doc_017.txt <--> doc_020.txt : 0.00%
# doc_018.txt <--> doc_019.txt : 0.00%
# doc_018.txt <--> doc_020.txt : 0.00%
# doc_019.txt <--> doc_020.txt : 0.00%

# %%
for n in range(1,6):
    score = ngram_similarity(doc1, doc2, n)
    print(n, score)
# Out:
# 1 0.450402144772118
# 2 0.11555555555555555
# 3 0.03908355795148248
# 4 0.014435695538057743
# 5 0.00390625
